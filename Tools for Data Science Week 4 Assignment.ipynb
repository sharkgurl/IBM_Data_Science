# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Cintia Campos**
# Ocean Artist and Marine Conservationist

# %% [markdown]
# *I am interested in data science with ocean science for marine conservation.*

# %% [markdown]
# ### The following code prints "Sharks are magnificent!"

# %%
print ("Sharks are magnificent!")
# Out:
# Sharks are magnificent!

# %% [markdown]
# Sharks I encountered while diving include:
#
# 1. [Great Hammerhead Sharks](https://en.wikipedia.org/wiki/Great_hammerhead)
# 2. [Whale Sharks](https://en.wikipedia.org/wiki/Whale_shark)
# 3. [Lemon Sharks](https://en.wikipedia.org/wiki/Lemon_shark)
# 4. [Bull Sharks](https://en.wikipedia.org/wiki/Bull_shark)
# 5. [Silky Sharks](https://en.wikipedia.org/wiki/Silky_shark)
# 6. [Nurse Sharks](https://en.wikipedia.org/wiki/Nurse_shark)
# 7. [Whitetip Reef Sharks](https://en.wikipedia.org/wiki/Whitetip_reef_shark)
# 8. [Zebra Sharks](https://en.wikipedia.org/wiki/Zebra_shark)
#
#
#
# ![CCA_8148-Edit-2.jpg](attachment:CCA_8148-Edit-2.jpg)
